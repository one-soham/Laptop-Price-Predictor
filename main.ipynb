# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("laptop_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# ...

# %%
df.duplicated().sum() #0 duplicate values
# Out:
# 0

# %%
df.isnull().sum() #Checking how many values are NULL per column
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df.drop("Unnamed: 0", axis=1, inplace=True) #Dropping the Unnamed:0 column since it has no valuable information

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df.Ram = df.Ram.str.replace("GB","")
df.Weight = df.Weight.str.replace("kg","")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df.Ram = df.Ram.astype("int32") #Converting both of these from object to int and float
df.Weight = df.Weight.astype("float32")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %%
sns.displot(df.Price)
# Out:
# C:\Users\soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.Company.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df.Company, y=df.Price)
plt.xticks(rotation="vertical")
plt.show()

# %%
df.TypeName.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df.TypeName, y=df.Price)
plt.xticks(rotation="vertical")
plt.show()

# %%
sns.scatterplot(x=df.Inches, y=df.Price)
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df.ScreenResolution.value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# ...

# %%
df["Touchscreen"] = df.ScreenResolution.apply(lambda x: 1 if "Touchscreen" in x else 0 ) #Filtering for touchscreen

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0
# ...

# %%
sns.barplot(x=df.Touchscreen, y=df.Price)
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df["Ips"] = df.ScreenResolution.apply(lambda x: 1 if "IPS" in x else 0 ) #Filtering for IPS panels

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
sns.barplot(x=df.Ips, y=df.Price)
# Out:
# <Axes: xlabel='Ips', ylabel='Price'>

# %%
new = df.ScreenResolution.str.split("x", n=1, expand=True) #expand converts new into Dataframe otherwise it would be Series

# %%
df["X_res"] = new[0]
df["Y_res"] = new[1]

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.X_res = df.X_res.apply(lambda x: x[-4:]) #Taking out last 4 digits from X_Res as they are the resolution value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   object
#  14  Y_res             1303 non-null   object
# dtypes: float32(1), float64(2), int32(1), int64(2), object(9)
# ...

# %%
df.X_res = df.X_res.astype("int32")
df.Y_res = df.Y_res.astype("int32")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int32
#  14  Y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
df["ppi"] = ((df.X_res**2 + df.Y_res**2)**0.5 / df.Inches).astype("float32")

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.drop(columns=["ScreenResolution", "Inches", "X_res", "Y_res"], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983002
# 1  127.677940
# ...

# %%
df.Cpu.value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
#Getting exact processor name for each entry
df["CpuName"] = df.Cpu.apply(lambda x: " ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi        CpuName
# ...

# %%
#We split CPUs into 5 categories: i3, i5, i7, other Intel, AMD
def fetch_processor(text):
    if text == "Intel Core i5" or text == "Intel Core i7" or text == "Intel Core i3":
        return text
    else:
        if text.split()[0] == "Intel":
            return "Other Intel Processors"
        else:
            return "AMD Processor"

# %%
df["CpuBrand"] = df.CpuName.apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi        CpuName       CpuBrand
# ...

# %%
df.CpuBrand.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='CpuBrand'>

# %%
sns.barplot(x=df.CpuBrand, y=df.Price)
plt.xticks(rotation="vertical")
plt.show()

# %%
df.Memory.value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['SSD'] = df.Memory.apply(lambda x: 4 if "SSD" in x else 0)
df['HDD'] = df.Memory.apply(lambda x: 1 if 'HDD' in x else 0)
df['Flash'] = df.Memory.apply(lambda x: 1 if 'Flash' in x else 0)
df['Hybrid'] = df.Memory.apply(lambda x: 1 if 'Hybrid' in x else 0)

# %%
df.SSD.value_counts()
# Out:
# SSD
# 4    843
# 0    460
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
# ...

# %%
df.drop(columns=["Memory"],inplace=True)

# %%
df.drop(columns=["Flash","Hybrid"],inplace=True) #Dropping Flash and Hybrid as they dont affect regression much

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi        CpuName       CpuBrand  SSD  HDD
# 0  226.983002  Intel Core i5  Intel Core i5    4    0
# 1  127.677940  Intel Core i5  Intel Core i5    0    0
# ...

# %%
df.drop(columns=["Cpu","CpuName"],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi       CpuBrand  SSD  HDD
# 0   71378.6832            0    1  226.983002  Intel Core i5    4    0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.212006  Intel Core i5    4    0
# 3  135195.3360            0    1  220.534622  Intel Core i7    4    0
# 4   96095.8080            0    1  226.983002  Intel Core i5    4    0

# %%
df.Gpu.value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df["GpuBrand"] = df.Gpu.apply(lambda x: x.split()[0]) #Since we don't have GPU memory, we can only use GPU name

# %%
df.GpuBrand.value_counts()
# Out:
# GpuBrand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi       CpuBrand  SSD  HDD GpuBrand
# 0   71378.6832            0    1  226.983002  Intel Core i5    4    0    Intel
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0    Intel
# 2   30636.0000            0    0  141.212006  Intel Core i5    4    0    Intel
# 3  135195.3360            0    1  220.534622  Intel Core i7    4    0      AMD
# 4   96095.8080            0    1  226.983002  Intel Core i5    4    0    Intel

# %%
df = df[df.GpuBrand != "ARM"] #Dropping the ARM GPU Laptop entry from df

# %%
df.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi       CpuBrand  SSD  HDD GpuBrand
# 0   71378.6832            0    1  226.983002  Intel Core i5    4    0    Intel
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0    Intel
# 2   30636.0000            0    0  141.212006  Intel Core i5    4    0    Intel
# 3  135195.3360            0    1  220.534622  Intel Core i7    4    0      AMD
# 4   96095.8080            0    1  226.983002  Intel Core i5    4    0    Intel

# %%
sns.barplot(x=df.GpuBrand,y=df.Price)
# Out:
# <Axes: xlabel='GpuBrand', ylabel='Price'>

# %%
df.drop(columns=["Gpu"],inplace=True)
# Out:
# C:\Users\soham\AppData\Local\Temp\ipykernel_28000\2541658551.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["Gpu"],inplace=True)

# %%
df.OpSys.value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
def os_chc(inp): #Splitting OS types into 3 categories
    if inp=="Windows 10" or inp=="Windows 10 S" or inp=="Windows 7":
        return "Windows"
    elif inp=="Mac OS X" or inp=="macOS":
        return "Mac"
    else:
        return "Others/No OS/ Linux"

# %%
df["os"] = df.OpSys.apply(os_chc)
# Out:
# C:\Users\soham\AppData\Local\Temp\ipykernel_28000\2949448585.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["os"] = df.OpSys.apply(os_chc)

# %%
df.sample(5)
# Out:
#      Company            TypeName  Ram       OpSys  Weight      Price  \
# 924   Lenovo  2 in 1 Convertible    8  Windows 10    1.37   97236.00
# 273   Lenovo  2 in 1 Convertible   16  Windows 10    1.36  133146.72
# 1110      HP            Notebook    8  Windows 10    1.16   90522.72
# 266     Asus  2 in 1 Convertible    8  Windows 10    1.10   79866.72
# 1259     MSI              Gaming    8  Windows 10    2.40   65481.12
#
#       Touchscreen  Ips         ppi                CpuBrand  SSD  HDD GpuBrand  \
# 924             1    1  165.632111           Intel Core i5    4    0    Intel
# 273             1    0  209.800690           Intel Core i7    4    0    Intel
# 1110            1    0  276.053528  Other Intel Processors    4    0    Intel
# 266             1    0  165.632111           Intel Core i7    4    0    Intel
# 1259            0    0  141.212006           Intel Core i7    4    1   Nvidia
#
#            os
# 924   Windows
# 273   Windows
# 1110  Windows
# 266   Windows
# ...

# %%
df.drop(columns=["OpSys"],inplace=True)
# Out:
# C:\Users\soham\AppData\Local\Temp\ipykernel_28000\1629809410.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=["OpSys"],inplace=True)

# %%
sns.barplot(x=df.os, y=df.Price)
# Out:
# <Axes: xlabel='os', ylabel='Price'>

# %%
sns.displot(df.Weight)
# Out:
# C:\Users\soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.scatterplot(x=df.Weight, y=df.Price)
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.corr(numeric_only=True)
# Out:
#                   Ram    Weight     Price  Touchscreen       Ips       ppi  \
# Ram          1.000000  0.383362  0.742905     0.118875  0.207949  0.305688
# Weight       0.383362  1.000000  0.209867    -0.293004  0.018643 -0.321883
# Price        0.742905  0.209867  1.000000     0.192917  0.253320  0.475368
# Touchscreen  0.118875 -0.293004  0.192917     1.000000  0.148026  0.458571
# Ips          0.207949  0.018643  0.253320     0.148026  1.000000  0.299142
# ppi          0.305688 -0.321883  0.475368     0.458571  0.299142  1.000000
# SSD          0.398160 -0.038576  0.513366     0.151463  0.230410  0.380613
# HDD         -0.010369  0.521475 -0.170436    -0.251309 -0.134494 -0.379972
#
#                   SSD       HDD
# Ram          0.398160 -0.010369
# Weight      -0.038576  0.521475
# Price        0.513366 -0.170436
# Touchscreen  0.151463 -0.251309
# Ips          0.230410 -0.134494
# ppi          0.380613 -0.379972
# SSD          1.000000 -0.559767
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.displot(np.log(df.Price))
# Out:
# C:\Users\soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
X = df.drop(columns="Price")
y = np.log(df.Price)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score, mean_absolute_error

from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.svm import SVR

#We will now test several algorithms

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983002
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.212006
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534622
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983002
#
#         CpuBrand  SSD  HDD GpuBrand                   os
# 0  Intel Core i5    4    0    Intel                  Mac
# 1  Intel Core i5    0    0    Intel                  Mac
# 2  Intel Core i5    4    0    Intel  Others/No OS/ Linux
# 3  Intel Core i7    4    0      AMD                  Mac
# 4  Intel Core i5    4    0    Intel                  Mac

# %%
#Linear Regression

step1 = ColumnTransformer(transformers=[("col_tnf", OneHotEncoder(sparse=False, drop="first"),
                                         [0,1,7,10,11])], remainder="passthrough")
step2 = LinearRegression()

pipe = Pipeline([("step1", step1), ("step2", step2)])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print("R2 Score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score:  0.8063926502956411
# MAE:  0.21217102051561082
# C:\Users\soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Ridge Regression

step1 = ColumnTransformer(transformers=[("col_tnf", OneHotEncoder(sparse=False, drop="first"),
                                         [0,1,7,10,11])], remainder="passthrough")
step2 = Ridge(alpha=10)

pipe = Pipeline([("step1", step1), ("step2", step2)])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print("R2 Score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score:  0.8086090287218922
# MAE:  0.21396285116331007
# C:\Users\soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Lasso Regression

step1 = ColumnTransformer(transformers=[("col_tnf", OneHotEncoder(sparse=False, drop="first"),
                                         [0,1,7,10,11])], remainder="passthrough")
step2 = Lasso(alpha=0.001)

pipe = Pipeline([("step1", step1), ("step2", step2)])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print("R2 Score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score:  0.8058613101456009
# MAE:  0.21443892166178385
# C:\Users\soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#K Nearest Neighbours

step1 = ColumnTransformer(transformers=[("col_tnf", OneHotEncoder(sparse=False, drop="first"),
                                         [0,1,7,10,11])], remainder="passthrough")
step2 = KNeighborsRegressor(n_neighbors=9)

pipe = Pipeline([("step1", step1), ("step2", step2)])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print("R2 Score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# C:\Users\soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 Score:  0.8029893173424422
# MAE:  0.20722306563273443

# %%
#Decision Tree

step1 = ColumnTransformer(transformers=[("col_tnf", OneHotEncoder(sparse=False, drop="first"),
                                         [0,1,7,10,11])], remainder="passthrough")
step2 = DecisionTreeRegressor(max_depth=7)

pipe = Pipeline([("step1", step1), ("step2", step2)])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print("R2 Score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score:  0.8340107047444327
# MAE:  0.1905988133898346
# C:\Users\soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#SVM
#K Nearest Neighbours

step1 = ColumnTransformer(transformers=[("col_tnf", OneHotEncoder(sparse=False, drop="first"),
                                         [0,1,7,10,11])], remainder="passthrough")
step2 = SVR(kernel="rbf",C=10000,epsilon=0.1) #r2 score peaks at n_neighbours=3

pipe = Pipeline([("step1", step1), ("step2", step2)])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print("R2 Score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# C:\Users\soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 Score:  0.8469092003804042
# MAE:  0.18632223536521395

# %%
#Random Forest

step1 = ColumnTransformer(transformers=[("col_tnf", OneHotEncoder(sparse=False, drop="first"),
                                         [0,1,7,10,11])], remainder="passthrough")
step2 = RandomForestRegressor(n_estimators=100, random_state=3, max_samples=0.5, max_features=0.75, max_depth=15)

pipe = Pipeline([("step1", step1), ("step2", step2)])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print("R2 Score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# C:\Users\soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 Score:  0.8780472350001602
# MAE:  0.1632537561417796

# %%
#AdaBoost

step1 = ColumnTransformer(transformers=[("col_tnf", OneHotEncoder(sparse=False, drop="first"),
                                         [0,1,7,10,11])], remainder="passthrough")
step2 = AdaBoostRegressor(n_estimators=100, learning_rate=1.0)

pipe = Pipeline([("step1", step1), ("step2", step2)])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print("R2 Score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))
# Out:
# R2 Score:  0.7833224626165094
# MAE:  0.23376797721092796
# C:\Users\soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
#Gradient Boost

step1 = ColumnTransformer(transformers=[("col_tnf", OneHotEncoder(sparse=False, drop="first"),
                                         [0,1,7,10,11])], remainder="passthrough")
step2 = GradientBoostingRegressor(n_estimators=1000)

pipe = Pipeline([("step1", step1), ("step2", step2)])

pipe.fit(X_train, y_train)
y_pred = pipe.predict(X_test)

print("R2 Score: ", r2_score(y_test, y_pred))
print("MAE: ", mean_absolute_error(y_test, y_pred))

#Ending algorithms -> Best result from Random Forest Algorithm
# Out:
# C:\Users\soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 Score:  0.8677796996083019
# MAE:  0.1625358536918328

# %%
#Exporting the model using Pickle
import pickle

# %%
pickle.dump(df, open("df.pkl", "wb"))
pickle.dump(pipe, open("pipe.pkl", "wb"))

# %%
df.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983002
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.212006
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534622
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983002
#
#         CpuBrand  SSD  HDD GpuBrand                   os
# 0  Intel Core i5    4    0    Intel                  Mac
# 1  Intel Core i5    0    0    Intel                  Mac
# 2  Intel Core i5    4    0    Intel  Others/No OS/ Linux
# 3  Intel Core i7    4    0      AMD                  Mac
# 4  Intel Core i5    4    0    Intel                  Mac
